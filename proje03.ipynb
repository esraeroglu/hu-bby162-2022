# %% [markdown]
# <a href="https://colab.research.google.com/github/esraeroglu/hu-bby162-2022/blob/main/proje03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print("Sınava hoş geldiniz..!")
print("Cevaplarınızı evet ya da hayır olarak giriniz")
sorular=["türkiyenin başkenti ankara mıdır?","hacettepe ankarada mıdır?","ankara marmara bölgesinde midir?","ankara kışın soğuk mudur?","hacettepenin bir kampüsü mü vardır?"]
cevaplar=["evet","evet","hayır","evet","hayır"]

puan=0

print("1." +sorular[0])
time.sleep(10)
cevap= input("cevabınız: ")
if cevap == cevaplar[0]:
  print("doğru cevap")
  puan += 20
else:
  print("yanlış cevap") 
print("2." +sorular[1])
time.sleep(10)
cevap= input("cevabınız: ")
if cevap == cevaplar[1]:
  print("doğru cevap")
  puan += 20
else:
  print("yanlış cevap ")
print("3." +sorular[2])
time.sleep(10)
cevap= input("cevabınız: ")
if cevap== cevaplar[2]:
  print("doğru cevap")
  puan += 20
else:
  print("yanlış cevap ")
print("4." +sorular[3])
time.sleep(10)
cevap= input("cevabınız: ")
if cevap  == cevaplar[3]:
  print("doğru cevap")
  puan += 20
else:
  print("yanlış cevap ") 
print("5." +sorular[4])
time.sleep(10)
cevap= input("cevabınız: ")
if cevap == cevaplar[4]:
  print("doğru cevap")
  puan += 20
else:
  print("yanlış cevap")
  
if puan > 60:
  print("tebrikler")

if puan < 60:
  print("kaybettiniz")
  print("teste tekrar girmek ister misin?")


print(puan)

yes = 'y'
no  = 'n'
if puan==0:
  print("doğrun yok -0 puan")
  print("kaybettin")
  tekrar = input("teste tekrar girmek ister misin? - yes/no")
  if tekrar == yes:
    print("test yeniden başlıyor")
  elif tekrar == no:
    print("keşke tekrar girseydin")
elif puan==1:
  print("bir doğrun var -20 puan")
  print("kaybettin")
  tekrar = input("teste tekrar girmek ister misin?")
  if tekrar == yes:
      print("test yeniden başlatılıyor")
  elif tekrar == no:
      print("keşke tekrar girseydin")
elif puan ==2:
   print("iki doğrun var -40 puan")
   print("kaybettin")
   tekrar = input("teste tekrar girmek istersin?")
   if tekrar == yes:
     print("test yeniden başlatılıyor")
   elif tekrar == no:
     print("keşke tekrar girseydin")
elif puan ==3:
  print("üç doğrun var -60 puan")
  print("tebriks")
elif puan ==4:
  print("dört doğrun var -80 puan")
  print("tebriks")
elif puan ==5:
  print("beş doğrun var -100 puan")
  print("tebriks")
